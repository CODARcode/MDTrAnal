# %%
import numpy as np
import math

from sklearn.decomposition import TruncatedSVD
from sklearn.utils.extmath import svd_flip, randomized_svd

from scipy.sparse.linalg import svds
from scipy.misc import imfilter
import scipy.ndimage as ndi

import scipy.io

from heapq import heappush, heappop

from random import uniform

import matplotlib
import matplotlib.pyplot as plt


from pprint import pprint

# %%
import os
import sys
pprint(os.getcwd())
pprint(os.path.realpath('../lib'))
sys.path.insert(0,os.path.realpath('../lib'))
pprint(sys.path)


from codar.oas.MDTrSampler import MDTrSampler, svd_wrapper
from codar.oas.util import MDTrMovieMaker
# Out:
# '/mnt/c/Users/shyyoo/repos/gh/MDTrAnal/src'
# '/mnt/c/Users/shyyoo/repos/gh/MDTrAnal/lib'
# ['/mnt/c/Users/shyyoo/repos/gh/MDTrAnal/lib',
#  '',
#  '/home/sjyoo/anaconda3/lib/python36.zip',
#  '/home/sjyoo/anaconda3/lib/python3.6',
#  '/home/sjyoo/anaconda3/lib/python3.6/lib-dynload',
#  '/home/sjyoo/anaconda3/lib/python3.6/site-packages',
#  '/home/sjyoo/anaconda3/lib/python3.6/site-packages/torchvision-0.2.0-py3.6.egg',
#  '/home/sjyoo/anaconda3/lib/python3.6/site-packages/IPython/extensions',
#  '/home/sjyoo/.ipython']

# %%
with open('../data/collision-ah.txt') as f:
    AT = f.read().splitlines()

# %%
mat= scipy.io.loadmat('../data/collision_0-5k.mat')
trace = mat['trace']
(x,y,z) = trace.shape
t2 = trace.reshape((x, y*z),order='C')

Ut, St, VTt = svd_wrapper(t2, 2, method='random')

c = Ut
s = St

n_dim=2
step=1000

fig, ax = plt.subplots()
ax.scatter(c[:,0],c[:,1], marker=".", c='b', s=0.5)
ax.set_xlim(min(c[:,0]), max(c[:,0]))
ax.set_ylim(min(c[:,1]), max(c[:,1]))
for i in range(0,x,step):
    ax.annotate(str(i),(c[i,0],c[i,1]))
plt.show()


mds =  MDTrSampler(y, n_dim = 2, conv_size = 50, n_samples=32, batch_size=128, manifold_size=64)

nmpsdm, psddu, prob_dist = mds.traj_char(c,s)

fig_b, ax_b = plt.subplots()
ax_b.scatter(range(0,nmpsdm.shape[0]),nmpsdm[:,0], marker=".", c="b", s=0.5)
ax_b.scatter(range(0,psddu.shape[0]),psddu[:],marker="x", c="r", s=0.2)
plt.show()

sampling_rate = 0.005
target, time_stamps = mds.batch_sampling(trace)


fig_c, ax_c =  plt.subplots()
ax_c.scatter(range(0,nmpsdm.shape[0]),nmpsdm[:,0], marker=".", c="b", s=0.5)
ax_c.scatter(time_stamps, np.ones(time_stamps.shape),marker="x",c="r", s=10.0)
plt.show()


mds2 = MDTrSampler(y, n_dim = 2, conv_size = 50, n_samples=32, batch_size=128, manifold_size=64)
for i in range(x): # not x
    mds2.adaptive_sampling_step(trace[i,:,:])


    
adaptive_samples = mds2.get_sampled_ts()
#pprint(mds2.get_sampled_ts())

#pprint(mds2.get_sampled_data())
#pprint(mds2.get_sampled_tsdata())

fig_d, ax_d = plt.subplots()
ax_d.scatter(range(0,nmpsdm.shape[0]),nmpsdm[:,0], marker=".", c="b", s=0.5)
ax_d.scatter(adaptive_samples, np.ones(len(adaptive_samples)),marker="x",c="r", s=10.0)
plt.show()

# %%
import logging
import time

logger = logging.getLogger('OAS')
logger.setLevel(logging.INFO)
streamHandler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter("%(asctime)s - %(filename)s - %(lineno)d - %(levelname)s - %(message)s")
formatter.converter = time.gmtime
streamHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.info("Logger was set")
# Out:
# 2018-08-03 06:36:09,060 - <ipython-input-5-3748869a030a> - 11 - INFO - Logger was set

# %%
cfg = {'jmol.jar'  : '/mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar',
       'width'     : 520,
       'height'    : 541,
       'video_name': 'test-out-integrated-angled-p3-v3.avi',
       'codec'     : 'XVID',#'XVID',#'X264', #'PIM1' for mpeg1
       'fps'       : 60
      }
data = mds2.get_sampled_tsdata()
pprint(data[0])

mm = MDTrMovieMaker(data, x, AT, cfg, logger=logger) # with logger
#mm = MDTrMovieMaker(data, 1024, AT, cfg)
mm.create_clip_bunch(view_angle=mds2.get_optimal_view_angle())
# Out:
# [0,
#  array([[ -35.316547,   30.354046,  128.358521],
#        [ -35.398651,   31.402622,  128.458618],
#        [ -35.013824,   30.064896,  127.403282],
#        ...,
#        [  28.096958,   54.240593,  129.726471],
#        [  28.109968,   53.246471,  129.659958],
#        [  28.607563,   54.388882,  130.548431]])]
# 5000
# 2018-08-03 05:22:57,290 - util.py - 162 - INFO - Executing : bash preprocess.sh
# 2018-08-03 05:22:57,437 - util.py - 162 - INFO - Executing : java  -jar /mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar -g 520x541 -s angle-script.jm -ixLo out-all.pdb
# 2018-08-03 05:24:08,121 - util.py - 171 - INFO - b'ImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\n'
# 2018-08-03 05:24:08,124 - util.py - 133 - INFO - Processing tst/out-00001.png
# 2018-08-03 05:24:08,635 - util.py - 133 - INFO - Processing tst/out-00002.png
# 2018-08-03 05:24:08,674 - util.py - 133 - INFO - Processing tst/out-00003.png
# 2018-08-03 05:24:08,798 - util.py - 133 - INFO - Processing tst/out-00004.png
# 2018-08-03 05:24:08,841 - util.py - 133 - INFO - Processing tst/out-00005.png
# 2018-08-03 05:24:08,946 - util.py - 133 - INFO - Processing tst/out-00006.png
# 2018-08-03 05:24:08,988 - util.py - 133 - INFO - Processing tst/out-00007.png
# 2018-08-03 05:24:09,142 - util.py - 133 - INFO - Processing tst/out-00008.png
# 2018-08-03 05:24:09,390 - util.py - 133 - INFO - Processing tst/out-00009.png
# 2018-08-03 05:24:09,724 - util.py - 133 - INFO - Processing tst/out-00010.png
# 2018-08-03 05:24:09,766 - util.py - 133 - INFO - Processing tst/out-00011.png
# 2018-08-03 05:24:10,070 - util.py - 133 - INFO - Processing tst/out-00012.png
# 2018-08-03 05:24:10,089 - util.py - 133 - INFO - Processing tst/out-00013.png
# 2018-08-03 05:24:10,224 - util.py - 133 - INFO - Processing tst/out-00014.png
# 2018-08-03 05:24:10,234 - util.py - 133 - INFO - Processing tst/out-00015.png
# 2018-08-03 05:24:10,503 - util.py - 133 - INFO - Processing tst/out-00016.png
# 2018-08-03 05:24:10,671 - util.py - 133 - INFO - Processing tst/out-00017.png
# 2018-08-03 05:24:10,706 - util.py - 133 - INFO - Processing tst/out-00018.png
# 2018-08-03 05:24:10,836 - util.py - 133 - INFO - Processing tst/out-00019.png
# 2018-08-03 05:24:11,257 - util.py - 133 - INFO - Processing tst/out-00020.png
# 2018-08-03 05:24:11,436 - util.py - 133 - INFO - Processing tst/out-00021.png
# 2018-08-03 05:24:11,579 - util.py - 133 - INFO - Processing tst/out-00022.png
# 2018-08-03 05:24:11,872 - util.py - 133 - INFO - Processing tst/out-00023.png
# 2018-08-03 05:24:12,205 - util.py - 133 - INFO - Processing tst/out-00024.png
# 2018-08-03 05:24:12,233 - util.py - 133 - INFO - Processing tst/out-00025.png
# 2018-08-03 05:24:12,458 - util.py - 133 - INFO - Processing tst/out-00026.png
# 2018-08-03 05:24:12,468 - util.py - 133 - INFO - Processing tst/out-00027.png
# 2018-08-03 05:24:13,025 - util.py - 133 - INFO - Processing tst/out-00028.png
# 2018-08-03 05:24:13,198 - util.py - 133 - INFO - Processing tst/out-00029.png
# 2018-08-03 05:24:13,818 - util.py - 133 - INFO - Processing tst/out-00030.png
# 2018-08-03 05:24:13,961 - util.py - 133 - INFO - Processing tst/out-00031.png
# 2018-08-03 05:24:13,975 - util.py - 133 - INFO - Processing tst/out-00032.png

# %%
adaptive_samples=mds2.get_sampled_ts()
adata = []
for s in adaptive_samples:
    adata.append([s, trace[s]])
#pprint(adata)
cfg = {'jmol.jar'  : '/mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar',
       'width'     : 520,
       'height'    : 541,
       'video_name': 'test-out-orient-pdb.avi',
       'codec'     : 'XVID',#'XVID',#'X264', #'PIM1' for mpeg1
       'fps'       : 60
      }
mm = MDTrMovieMaker(adata, x, AT, cfg, logger=logger) # with logger
#mm = MDTrMovieMaker(data, 1024, AT, cfg)
mm.create_clip_bunch()
# Out:
# 5000
# 2018-08-03 06:37:07,197 - util.py - 162 - INFO - Executing : /bin/bash  preprocess.sh
# 2018-08-03 06:37:07,362 - util.py - 162 - INFO - Executing : java  -jar /mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar -g 520x541 -s angle-script.jm -ixLo out-all.pdb
# 2018-08-03 06:38:08,915 - util.py - 171 - INFO - b'ImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\n'
# 2018-08-03 06:38:08,926 - util.py - 133 - INFO - Processing tst/out-00001.png
# 2018-08-03 06:38:09,211 - util.py - 133 - INFO - Processing tst/out-00002.png
# 2018-08-03 06:38:09,341 - util.py - 133 - INFO - Processing tst/out-00003.png
# 2018-08-03 06:38:09,368 - util.py - 133 - INFO - Processing tst/out-00004.png
# 2018-08-03 06:38:09,717 - util.py - 133 - INFO - Processing tst/out-00005.png
# 2018-08-03 06:38:09,879 - util.py - 133 - INFO - Processing tst/out-00006.png
# 2018-08-03 06:38:10,001 - util.py - 133 - INFO - Processing tst/out-00007.png
# 2018-08-03 06:38:10,364 - util.py - 133 - INFO - Processing tst/out-00008.png
# 2018-08-03 06:38:10,581 - util.py - 133 - INFO - Processing tst/out-00009.png
# 2018-08-03 06:38:10,806 - util.py - 133 - INFO - Processing tst/out-00010.png
# 2018-08-03 06:38:10,821 - util.py - 133 - INFO - Processing tst/out-00011.png
# 2018-08-03 06:38:10,849 - util.py - 133 - INFO - Processing tst/out-00012.png
# 2018-08-03 06:38:11,094 - util.py - 133 - INFO - Processing tst/out-00013.png
# 2018-08-03 06:38:11,122 - util.py - 133 - INFO - Processing tst/out-00014.png
# 2018-08-03 06:38:11,410 - util.py - 133 - INFO - Processing tst/out-00015.png
# 2018-08-03 06:38:11,502 - util.py - 133 - INFO - Processing tst/out-00016.png
# 2018-08-03 06:38:11,532 - util.py - 133 - INFO - Processing tst/out-00017.png
# 2018-08-03 06:38:11,556 - util.py - 133 - INFO - Processing tst/out-00018.png
# 2018-08-03 06:38:11,649 - util.py - 133 - INFO - Processing tst/out-00019.png
# 2018-08-03 06:38:11,675 - util.py - 133 - INFO - Processing tst/out-00020.png
# 2018-08-03 06:38:12,065 - util.py - 133 - INFO - Processing tst/out-00021.png
# 2018-08-03 06:38:12,173 - util.py - 133 - INFO - Processing tst/out-00022.png
# 2018-08-03 06:38:12,191 - util.py - 133 - INFO - Processing tst/out-00023.png
# 2018-08-03 06:38:12,406 - util.py - 133 - INFO - Processing tst/out-00024.png
# 2018-08-03 06:38:12,449 - util.py - 133 - INFO - Processing tst/out-00025.png
# 2018-08-03 06:38:13,014 - util.py - 133 - INFO - Processing tst/out-00026.png
# 2018-08-03 06:38:13,054 - util.py - 133 - INFO - Processing tst/out-00027.png
# 2018-08-03 06:38:13,154 - util.py - 133 - INFO - Processing tst/out-00028.png
# 2018-08-03 06:38:13,661 - util.py - 133 - INFO - Processing tst/out-00029.png
# 2018-08-03 06:38:13,773 - util.py - 133 - INFO - Processing tst/out-00030.png
# 2018-08-03 06:38:13,781 - util.py - 133 - INFO - Processing tst/out-00031.png
# 2018-08-03 06:38:13,886 - util.py - 133 - INFO - Processing tst/out-00032.png

# %%
bdata= []
for s in time_stamps.tolist():
    bdata.append([round(s), trace[round(s)]])
#pprint(adata)
cfg = {'jmol.jar'  : '/mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar',
       'width'     : 520,
       'height'    : 541,
       'video_name': 'batch-out-orient-pdb.avi',
       'codec'     : 'XVID',#'XVID',#'X264', #'PIM1' for mpeg1
       'fps'       : 60
      }
mm = MDTrMovieMaker(bdata, x, AT, cfg, logger=logger) # with logger
#mm = MDTrMovieMaker(data, 1024, AT, cfg)
mm.create_clip_bunch()
# Out:
# 5000
# 2018-08-03 06:47:56,104 - util.py - 162 - INFO - Executing : /bin/bash  preprocess.sh
# 2018-08-03 06:47:56,272 - util.py - 162 - INFO - Executing : java  -jar /mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar -g 520x541 -s angle-script.jm -ixLo out-all.pdb
# 2018-08-03 06:48:58,436 - util.py - 171 - INFO - b'ImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\n'
# 2018-08-03 06:48:58,443 - util.py - 133 - INFO - Processing tst/out-00001.png
# 2018-08-03 06:49:00,599 - util.py - 133 - INFO - Processing tst/out-00002.png
# 2018-08-03 06:49:00,666 - util.py - 133 - INFO - Processing tst/out-00003.png
# 2018-08-03 06:49:00,689 - util.py - 133 - INFO - Processing tst/out-00004.png
# 2018-08-03 06:49:00,710 - util.py - 133 - INFO - Processing tst/out-00005.png
# 2018-08-03 06:49:00,728 - util.py - 133 - INFO - Processing tst/out-00006.png
# 2018-08-03 06:49:00,739 - util.py - 133 - INFO - Processing tst/out-00007.png
# 2018-08-03 06:49:00,756 - util.py - 133 - INFO - Processing tst/out-00008.png
# 2018-08-03 06:49:00,780 - util.py - 133 - INFO - Processing tst/out-00009.png
# 2018-08-03 06:49:00,801 - util.py - 133 - INFO - Processing tst/out-00010.png
# 2018-08-03 06:49:00,821 - util.py - 133 - INFO - Processing tst/out-00011.png
# 2018-08-03 06:49:00,848 - util.py - 133 - INFO - Processing tst/out-00012.png
# 2018-08-03 06:49:00,882 - util.py - 133 - INFO - Processing tst/out-00013.png
# 2018-08-03 06:49:00,966 - util.py - 133 - INFO - Processing tst/out-00014.png
# 2018-08-03 06:49:02,012 - util.py - 133 - INFO - Processing tst/out-00015.png
# 2018-08-03 06:49:02,614 - util.py - 133 - INFO - Processing tst/out-00016.png
# 2018-08-03 06:49:02,824 - util.py - 133 - INFO - Processing tst/out-00017.png
# 2018-08-03 06:49:02,890 - util.py - 133 - INFO - Processing tst/out-00018.png
# 2018-08-03 06:49:02,903 - util.py - 133 - INFO - Processing tst/out-00019.png
# 2018-08-03 06:49:02,912 - util.py - 133 - INFO - Processing tst/out-00020.png
# 2018-08-03 06:49:02,925 - util.py - 133 - INFO - Processing tst/out-00021.png
# 2018-08-03 06:49:02,938 - util.py - 133 - INFO - Processing tst/out-00022.png
# 2018-08-03 06:49:02,950 - util.py - 133 - INFO - Processing tst/out-00023.png
# 2018-08-03 06:49:02,962 - util.py - 133 - INFO - Processing tst/out-00024.png
# 2018-08-03 06:49:02,971 - util.py - 133 - INFO - Processing tst/out-00025.png
# 2018-08-03 06:49:02,984 - util.py - 133 - INFO - Processing tst/out-00026.png
# 2018-08-03 06:49:02,997 - util.py - 133 - INFO - Processing tst/out-00027.png
# 2018-08-03 06:49:03,013 - util.py - 133 - INFO - Processing tst/out-00028.png
# 2018-08-03 06:49:03,043 - util.py - 133 - INFO - Processing tst/out-00029.png
# 2018-08-03 06:49:03,126 - util.py - 133 - INFO - Processing tst/out-00030.png
# 2018-08-03 06:49:03,230 - util.py - 133 - INFO - Processing tst/out-00031.png
# 2018-08-03 06:49:03,479 - util.py - 133 - INFO - Processing tst/out-00032.png

# %%
udata= []
for i in range(0,x, int(x/31)):
    udata.append([i, trace[i]])
#pprint(adata)
cfg = {'jmol.jar'  : '/mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar',
       'width'     : 520,
       'height'    : 541,
       'video_name': 'unis-out-orient-pdb.avi',
       'codec'     : 'XVID',#'XVID',#'X264', #'PIM1' for mpeg1
       'fps'       : 60
      }
mm = MDTrMovieMaker(udata, x, AT, cfg, logger=logger) # with logger
#mm = MDTrMovieMaker(data, 1024, AT, cfg)
mm.create_clip_bunch()
# Out:
# 5000
# 2018-08-03 07:35:39,400 - util.py - 162 - INFO - Executing : /bin/bash  preprocess.sh
# 2018-08-03 07:35:39,656 - util.py - 162 - INFO - Executing : java  -jar /mnt/c/Users/shyyoo/Downloads/jmol-14.29.17/Jmol.jar -g 520x541 -s angle-script.jm -ixLo out-all.pdb
# 2018-08-03 07:38:45,965 - util.py - 171 - INFO - b'ImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\nImageEncoder width height 520 541\n'
# 2018-08-03 07:38:45,973 - util.py - 133 - INFO - Processing tst/out-00001.png
# 2018-08-03 07:38:46,483 - util.py - 133 - INFO - Processing tst/out-00002.png
# 2018-08-03 07:38:47,058 - util.py - 133 - INFO - Processing tst/out-00003.png
# 2018-08-03 07:38:47,514 - util.py - 133 - INFO - Processing tst/out-00004.png
# 2018-08-03 07:38:48,025 - util.py - 133 - INFO - Processing tst/out-00005.png
# 2018-08-03 07:38:48,530 - util.py - 133 - INFO - Processing tst/out-00006.png
# 2018-08-03 07:38:49,110 - util.py - 133 - INFO - Processing tst/out-00007.png
# 2018-08-03 07:38:49,723 - util.py - 133 - INFO - Processing tst/out-00008.png
# 2018-08-03 07:38:50,315 - util.py - 133 - INFO - Processing tst/out-00009.png
# 2018-08-03 07:38:50,910 - util.py - 133 - INFO - Processing tst/out-00010.png
# 2018-08-03 07:38:51,520 - util.py - 133 - INFO - Processing tst/out-00011.png
# 2018-08-03 07:38:52,101 - util.py - 133 - INFO - Processing tst/out-00012.png
# 2018-08-03 07:38:52,671 - util.py - 133 - INFO - Processing tst/out-00013.png
# 2018-08-03 07:38:53,296 - util.py - 133 - INFO - Processing tst/out-00014.png
# 2018-08-03 07:38:53,870 - util.py - 133 - INFO - Processing tst/out-00015.png
# 2018-08-03 07:38:54,482 - util.py - 133 - INFO - Processing tst/out-00016.png
# 2018-08-03 07:38:55,071 - util.py - 133 - INFO - Processing tst/out-00017.png
# 2018-08-03 07:38:55,647 - util.py - 133 - INFO - Processing tst/out-00018.png
# 2018-08-03 07:38:56,225 - util.py - 133 - INFO - Processing tst/out-00019.png
# 2018-08-03 07:38:56,818 - util.py - 133 - INFO - Processing tst/out-00020.png
# 2018-08-03 07:38:57,420 - util.py - 133 - INFO - Processing tst/out-00021.png
# 2018-08-03 07:38:58,024 - util.py - 133 - INFO - Processing tst/out-00022.png
# 2018-08-03 07:38:58,653 - util.py - 133 - INFO - Processing tst/out-00023.png
# 2018-08-03 07:38:59,222 - util.py - 133 - INFO - Processing tst/out-00024.png
# 2018-08-03 07:38:59,821 - util.py - 133 - INFO - Processing tst/out-00025.png
# 2018-08-03 07:39:00,422 - util.py - 133 - INFO - Processing tst/out-00026.png
# 2018-08-03 07:39:01,027 - util.py - 133 - INFO - Processing tst/out-00027.png
# 2018-08-03 07:39:01,598 - util.py - 133 - INFO - Processing tst/out-00028.png
# 2018-08-03 07:39:02,178 - util.py - 133 - INFO - Processing tst/out-00029.png
# 2018-08-03 07:39:02,719 - util.py - 133 - INFO - Processing tst/out-00030.png
# 2018-08-03 07:39:03,285 - util.py - 133 - INFO - Processing tst/out-00031.png
# 2018-08-03 07:39:03,908 - util.py - 133 - INFO - Processing tst/out-00032.png
